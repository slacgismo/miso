# %%
import os, sys
sys.path.append(os.getcwd().replace("/docs","/source"))
import miso

# %%
help('miso')
# Out:
# Help on module miso:
#
# NAME
#     miso - MISO Real-Time Final Market LMPs
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         MisoInvalidDataFormat
#         MisoNodeNotFound
#         MisoTypeNotFound
#         MisoValueNotFound
#     builtins.object
#         Data
#         Node
#         Zone
#
#     class Data(builtins.object)
#      |  Data(dataset, day)
#      |
#      |  MISO LMP Data Downloader
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, dataset, day)
#      |      LMP data downloader constructor
#      |
#      |      ARGUMENTS
#      |
#      |      dataset - download dataset (see DATAFORMATS)
#      |      day - day to download (as datetime)
#      |
#      |  stream(self)
#      |      Returns data as a stream in CSV format
#      |
#      |  string(self)
#      |      Returns data as a string in CSV format
#      |
#      |  ----------------------------------------------------------------------
# ...
